# %% [markdown]
# ## Conclusion
# This concludes your starter analysis! To go forward from here, click the blue "Fork Notebook" button at the top of this kernel. This will create a copy of the code and environment for you to edit. Delete, modify, and add code as you please. Happy Kaggling!

# %%
import pandas as pd
# Load the CSV files
address_df = pd.read_csv('data/Address_short.csv')
diabetes_df = pd.read_csv('data/Diabetes_Prevalence_GIS.csv')
neighborhood_df = pd.read_csv('data/Neighborhood.csv')
neighborhood_health_df = pd.read_csv('data/NeighborhoodHealth.csv')
population_density_df = pd.read_csv('data/Population_Density_GIS.csv')
hospital_df = pd.read_csv('data/SantaClaraHospitals.csv')
econ_indicators_df = pd.read_csv('data/econ_indicators_q22017.csv')

# %%
#Inspect the first few rows of each dataset
print(address_df.head())
print(diabetes_df.head())
print(econ_indicators_df.head())
print(neighborhood_df.head())
print(neighborhood_health_df.head())
print(population_density_df.head())
print(hospital_df.head())

# %%
# Check for missing values
print(address_df.isnull().sum())
print(diabetes_df.isnull().sum())
print(neighborhood_df.isnull().sum())
print(neighborhood_health_df.isnull().sum())
print(population_density_df.isnull().sum())
print(hospital_df.isnull().sum())
print(econ_indicators_df.isnull().sum())

# %%
import os
# Create the directory if it doesn't exist
os.makedirs(r'C:\NGOCS\NGOC\OMDENA PROJECT\DATASETS FROM MAHESH\Cleaned after raw datasets', exist_ok=True)

# %%
# Cleaning all other datasets
# address_short.csv
address_df_clean = address_df.copy()
address_df_clean.fillna(0, inplace=True)
address_df_clean.drop_duplicates(inplace=True)

# Diabetes_Prevalence_GIS.csv
diabetes_df_clean = diabetes_df.copy()
diabetes_df_clean.fillna(0, inplace=True)
diabetes_df_clean.drop_duplicates(inplace=True)

# econ_indicators_q22017.csv
econ_df_clean = econ_indicators_df.copy()
econ_df_clean.fillna(0, inplace=True)
econ_df_clean.drop_duplicates(inplace=True)

# Neighborhood.csv
neighborhood_df_clean = neighborhood_df.copy()
neighborhood_df_clean.fillna(0, inplace=True)
neighborhood_df_clean.drop_duplicates(inplace=True)

# NeighborhoodHealth.csv
neighborhood_health_df_clean = neighborhood_health_df.copy()
neighborhood_health_df_clean.fillna(0, inplace=True)
neighborhood_health_df_clean.drop_duplicates(inplace=True)

# Population_Density_GIS.csv
population_df_clean = population_density_df.copy()
population_df_clean.fillna(0, inplace=True)
population_df_clean.drop_duplicates(inplace=True)

# SantaClaraHospitals.csv
hospitals_df_clean = hospital_df.copy()
hospitals_df_clean.fillna(0, inplace=True)
hospitals_df_clean.drop_duplicates(inplace=True)

# Save cleaned datasets to new CSV files
address_df_clean.to_csv(r'C:\NGOCS\NGOC\OMDENA PROJECT\DATASETS FROM MAHESH\Cleaned after raw datasets/Cleaned_address_short.csv', index=False)
diabetes_df_clean.to_csv(r'C:\NGOCS\NGOC\OMDENA PROJECT\DATASETS FROM MAHESH\Cleaned after raw datasets/Cleaned_Diabetes_Prevalence_GIS.csv', index=False)
econ_df_clean.to_csv(r'C:\NGOCS\NGOC\OMDENA PROJECT\DATASETS FROM MAHESH\Cleaned after raw datasets/Cleaned_econ_indicators_q22017.csv', index=False)
neighborhood_df_clean.to_csv(r'C:\NGOCS\NGOC\OMDENA PROJECT\DATASETS FROM MAHESH\Cleaned after raw datasets/Cleaned_Neighborhood.csv', index=False)
neighborhood_health_df_clean.to_csv(r'C:\NGOCS\NGOC\OMDENA PROJECT\DATASETS FROM MAHESH\Cleaned after raw datasets/Cleaned_NeighborhoodHealth.csv', index=False)
population_df_clean.to_csv(r'C:\NGOCS\NGOC\OMDENA PROJECT\DATASETS FROM MAHESH\Cleaned after raw datasets/Cleaned_Population_Density_GIS.csv', index=False)
hospitals_df_clean.to_csv(r'C:\NGOCS\NGOC\OMDENA PROJECT\DATASETS FROM MAHESH\Cleaned after raw datasets/Cleaned_SantaClaraHospitals.csv', index=False)

cleaned_files = [
    r'C:\NGOCS\NGOC\OMDENA PROJECT\DATASETS FROM MAHESH\Cleaned after raw datasets/Cleaned_address_short.csv',
    r'C:\NGOCS\NGOC\OMDENA PROJECT\DATASETS FROM MAHESH\Cleaned after raw datasets/Cleaned_Diabetes_Prevalence_GIS.csv',
    r'C:\NGOCS\NGOC\OMDENA PROJECT\DATASETS FROM MAHESH\Cleaned after raw datasets/Cleaned_econ_indicators_q22017.csv',
    r'C:\NGOCS\NGOC\OMDENA PROJECT\DATASETS FROM MAHESH\Cleaned after raw datasets/Cleaned_Neighborhood.csv',
    r'C:\NGOCS\NGOC\OMDENA PROJECT\DATASETS FROM MAHESH\Cleaned after raw datasets/Cleaned_NeighborhoodHealth.csv',
    r'C:\NGOCS\NGOC\OMDENA PROJECT\DATASETS FROM MAHESH\Cleaned after raw datasets/Cleaned_Population_Density_GIS.csv',
    r'C:\NGOCS\NGOC\OMDENA PROJECT\DATASETS FROM MAHESH\Cleaned after raw datasets/Cleaned_SantaClaraHospitals.csv'
]

cleaned_files
# Out:
# ['C:\\NGOCS\\NGOC\\OMDENA PROJECT\\DATASETS FROM MAHESH\\Cleaned after raw datasets/Cleaned_address_short.csv',
#  'C:\\NGOCS\\NGOC\\OMDENA PROJECT\\DATASETS FROM MAHESH\\Cleaned after raw datasets/Cleaned_Diabetes_Prevalence_GIS.csv',
#  'C:\\NGOCS\\NGOC\\OMDENA PROJECT\\DATASETS FROM MAHESH\\Cleaned after raw datasets/Cleaned_econ_indicators_q22017.csv',
#  'C:\\NGOCS\\NGOC\\OMDENA PROJECT\\DATASETS FROM MAHESH\\Cleaned after raw datasets/Cleaned_Neighborhood.csv',
#  'C:\\NGOCS\\NGOC\\OMDENA PROJECT\\DATASETS FROM MAHESH\\Cleaned after raw datasets/Cleaned_NeighborhoodHealth.csv',
#  'C:\\NGOCS\\NGOC\\OMDENA PROJECT\\DATASETS FROM MAHESH\\Cleaned after raw datasets/Cleaned_Population_Density_GIS.csv',
#  'C:\\NGOCS\\NGOC\\OMDENA PROJECT\\DATASETS FROM MAHESH\\Cleaned after raw datasets/Cleaned_SantaClaraHospitals.csv']
